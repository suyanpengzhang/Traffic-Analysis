# %%
import pickle
import pandas as pd
import warnings

# %%
with open('2022_10.pkl', 'rb') as file:
    flow = pickle.load(file)

# %%
volume_2022_1 ={}
# Out:
#                    0          1    2  3           4         5    zip
# 0           1473-1-1   0.000000    0  0  2022/10/13  23:59:06  90212
# 1            477-5-1   0.000000    0  0  2022/10/13  23:59:06  90263
# 2          22043-9-2   0.000000    0  0  2022/10/13  23:59:06  93550
# 3         22043-18-3   0.000000    0  0  2022/10/13  23:59:06  93552
# 4            543-2-1   0.000000    0  0  2022/10/13  23:59:06  90265
# ...              ...        ...  ... ..         ...       ...    ...
# 43086468      4094-E  23.617153   76  0  2022/10/14  23:59:22  90045
# 43086469      6229-S  26.724674  208  2  2022/10/14  23:59:22  91601
# 43086470      6229-N  27.967682  170  1  2022/10/14  23:59:22  91601
# 43086471     17047-S  26.103170  123  1  2022/10/14  23:59:22  90731
# 43086472     10172-E  31.696707  309  1  2022/10/14  23:59:22  91330
#
# [43086473 rows x 7 columns]

# %%
with open('data10.p', 'rb') as file:
    flow = pickle.load(file)
with open('sensor_lat.pickle', 'rb') as file:
    sslat = pickle.load(file)
with open('sensor_long.pickle', 'rb') as file:
    sslong = pickle.load(file)
with open('Arterial_ID_zip.p', 'rb') as file:
    tozip = pickle.load(file)
tozips ={}
for i in tozip.index:
    tozips[tozip['ID'][i]] = tozip['Zipcode'][i]
volume = [flow['Volume_sum_2020/10/03'][i]/flow['Volume_count_2020/10/03'][i]for i in flow.index]
volume = pd.Series(volume,index= flow.index)
flow['volume']=volume
data = flow[['volume']]
zips = []
for i in data.index:
    if i in tozips:
        zips.append(tozips[i])
    else:
        zips.append(0)
zips = pd.Series(zips,index = data.index)
data['zip'] = zips
data = data[data['zip']=='90013']
# Out:
# /var/folders/b3/kkdtnh4d4gjgrk45d_yrf4100000gn/T/ipykernel_46982/1029407568.py:12: RuntimeWarning: invalid value encountered in scalar divide
#   volume = [flow['Volume_sum_2020/10/03'][i]/flow['Volume_count_2020/10/03'][i]for i in flow.index]
# /var/folders/b3/kkdtnh4d4gjgrk45d_yrf4100000gn/T/ipykernel_46982/1029407568.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['zip'] = zips

# %%
common_list = list(set(flow_90013_10_03[0]).intersection(set(data.index)))
data2020 = data[data.index.isin(common_list)]
data2022 = flow_90013_10_03[flow_90013_10_03[0].isin(common_list)]
print('2020',np.mean(data2020[data2020['volume']>0]['volume']))
print('2022',np.mean(data2022[data2022[2]>0][2]))
# Out:
# 2020 83.70218777701173
# 2022 155.81024498886416

# %%
flow_90013_common = flow_90013_jan[flow_90013_jan[0].isin(common_list)]

# %%
np.mean(flow_90013_common[flow_90013_common[2]>0][2])
# Out:
# 1.6675627360582803

# %%
flow_90013_common=flow_90013_common[flow_90013_common[4]=='2022/01/03']
time = [pd.to_datetime(flow_90013_common[5][i])-pd.to_datetime('2023/09/07') for i in flow_90013_common.index]
new_time = [x.total_seconds()/3600 for x in time]
new_time = pd.Series(new_time,index = flow_90013_common.index)
flow_90013_common['time'] = new_time

# %%
# select zipcode 90013
flow_90013 = flow[flow['zip']=='91405']

# %%
#select oct 17, which is Monday in 2022, Wednesday in 2018
flow_90013_10_03 = flow_90013[flow_90013[4]=='2022/10/03']

# %%
time = [pd.to_datetime(flow_90013_10_03[5][i])-pd.to_datetime('2023/09/07') for i in flow_90013_10_03.index]
new_time = [x.total_seconds()/3600 for x in time]
new_time = pd.Series(new_time,index = flow_90013_10_03.index)
flow_90013_10_03['time'] = new_time
# Out:
# /var/folders/b3/kkdtnh4d4gjgrk45d_yrf4100000gn/T/ipykernel_44143/1965727255.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flow_90013_10_03['time'] = new_time

# %%
flow_90013_10_03[0].value_counts()
# Out:
# 2032-N    200
# 2227-W    200
# 2221-E    200
# 2233-E    200
# 2232-N    200
# 2232-S    200
# 2220-E    200
# 2222-E    200
# 5236-S    200
# 2046-N    200
# 2033-N    200
# 2105-N    200
# 2036-W    200
# 2359-S    200
# 2079-S    200
# 2235-N    200
# 2076-E    200
# 5242-N    200
# 2220-W    200
# 2257-S    200
# 2242-S    200
# 2236-S    200
# 2076-S    200
# 2037-S    200
# 2076-N    200
# 5250-S    200
# 2227-S    200
# 2227-N    200
# 2054-E    200
# 2077-S    200
# 2222-N    200
# 2222-S    200
# 2033-W    200
# 2105-S    200
# 2032-W    200
# 2226-W    200
# 2236-W    200
# 2235-S    200
# 2235-W    200
# 2075-S    200
# 2055-E    200
# Name: 0, dtype: int64

# %%
import matplotlib.pyplot as plt

df_to_plot = flow_90013_10_03[flow_90013_10_03[0] == '10006-W']
df_to_plot = df_to_plot.sort_values(by='time', ascending=True)
# Plot x vs. y
df_to_plot.plot(x='time', y=2, kind='line', marker='o', linestyle='-')
plt.xlabel('Time')
plt.ylabel('Volume')
plt.grid(True)
plt.show()

# %%
x = list(set(flow_90013_10_03['time'].values))
y = []
for timestamp in x:
    temp_frame = flow_90013_10_03[flow_90013_10_03['time']==timestamp]
    avg_flow = np.mean(temp_frame[2])
    y.append(avg_flow)

# %%
data = {'x': x,
        'y': y}

# Create a DataFrame from the data
df = pd.DataFrame(data)
df = df.sort_values(by='x', ascending=True)

# Plot x vs. y
df.plot(x='x', y='y', kind='line', marker='o', linestyle='-')
#df_to_plot.plot(x='time', y=2, kind='line', marker='o', linestyle='-')
plt.xlabel('Time')
plt.ylabel('Volume')
plt.grid(True)
plt.show()

# %%
x = list(set(flow_90013_common['time'].values))
y = []
for timestamp in x:
    temp_frame = flow_90013_common[flow_90013_common['time']==timestamp]
    avg_flow = np.mean(temp_frame[2])
    y.append(avg_flow)

# %%
data = {'x': x,
        'y': y}

# Create a DataFrame from the data
df = pd.DataFrame(data)
df = df.sort_values(by='x', ascending=True)

# Plot x vs. y
df.plot(x='x', y='y', kind='line', marker='o', linestyle='-')
#df_to_plot.plot(x='time', y=2, kind='line', marker='o', linestyle='-')
plt.xlabel('Time')
plt.ylabel('Volume')
plt.grid(True)
plt.show()

# %%
x
# Out:
# [0.5541666666666667,
#  0.6375,
#  0.8038888888888889,
#  1.0541666666666667,
#  2.14,
#  2.220833333333333,
#  2.720833333333333,
#  2.970833333333333,
#  6.054166666666666,
#  3.220833333333333,
#  3.970833333333333,
#  4.220833333333333,
#  4.470833333333333,
#  4.720833333333333,
#  5.220833333333333,
#  6.220833333333333,
#  7.054444444444444,
#  8.055,
#  9.054166666666667,
#  10.054444444444444,
#  11.054166666666667,
#  6.887777777777778,
#  8.387777777777778,
#  8.887777777777778,
#  9.304166666666667,
#  9.637777777777778,
#  10.137777777777778,
#  10.387777777777778,
#  10.887777777777778,
#  11.137777777777778,
#  11.887777777777778,
#  3.725277777777778,
#  0.3875,
#  0.1375,
#  4.887222222222222,
#  1.2208333333333334,
#  1.4708333333333334,
#  1.7208333333333334,
#  1.9708333333333334,
#  4.970833333333333,
#  5.470833333333333,
#  5.720833333333333,
#  5.970833333333333,
#  6.470833333333333,
#  6.554444444444444,
#  6.720833333333333,
#  6.970833333333333,
#  7.220833333333333,
#  7.304444444444444,
#  7.470833333333333,
#  7.554444444444444,
#  7.804444444444444,
#  7.970833333333333,
#  8.220833333333333,
#  2.5544444444444445,
#  8.304444444444444,
#  8.470833333333333,
#  8.554444444444444,
#  8.720833333333333,
#  3.0544444444444445,
#  3.5544444444444445,
#  8.804444444444444,
#  9.554444444444444,
#  9.720833333333333,
#  9.804444444444444,
#  9.970833333333333,
#  10.220833333333333,
#  10.304444444444444,
#  10.470833333333333,
#  10.554444444444444,
#  10.804444444444444,
#  10.970833333333333,
#  11.220833333333333,
#  11.304444444444444,
#  11.470833333333333,
#  11.554444444444444,
#  11.720833333333333,
#  0.22083333333333333,
#  0.4708333333333333,
#  0.7208333333333333,
#  0.9708333333333333,
#  0.8872222222222222,
#  8.1375,
#  8.6375,
#  9.1375,
#  9.475555555555555,
#  9.8875,
#  10.6375,
#  1.1375,
#  1.3875,
#  1.6375,
#  1.8875,
#  11.3875,
#  11.6375,
#  2.3875,
#  2.471111111111111,
#  2.6375,
#  2.8875,
#  3.1375,
#  3.3875,
#  3.471111111111111,
#  3.8875,
#  4.1375,
#  4.3875,
#  4.6375,
#  5.1375,
#  5.3875,
#  5.6375,
#  5.8875,
#  11.804444444444444,
#  6.1375,
#  6.3875,
#  6.6375,
#  7.1375,
#  7.3875,
#  7.6375,
#  7.721111111111111,
#  7.8875,
#  3.8047222222222223,
#  0.30416666666666664,
#  8.971944444444444,
#  9.221111111111112,
#  10.721111111111112,
#  0.05416666666666667,
#  4.054166666666666,
#  4.304166666666666,
#  4.554166666666666,
#  4.804166666666666,
#  5.054166666666666,
#  5.304166666666666,
#  5.554166666666666,
#  5.804166666666666,
#  11.970833333333333,
#  6.304166666666666,
#  6.804166666666666,
#  1.3041666666666667,
#  1.5541666666666667,
#  1.8041666666666667,
#  2.3041666666666667,
#  2.8041666666666667,
#  3.3041666666666667]

# %%
flow_90013_common[flow_90013_common[0]=='2222-S']
# Out:
#                0          1  2  3           4         5    zip       time
# 49191937  2222-S  19.266626  1  0  2022/01/03  00:03:15  90013   0.054167
# 49277940  2222-S  19.266626  1  0  2022/01/03  00:13:15  90013   0.220833
# 49308725  2222-S  19.266626  1  0  2022/01/03  00:18:15  90013   0.304167
# 49388349  2222-S  19.266626  1  0  2022/01/03  00:28:15  90013   0.470833
# 49425510  2222-S  19.266626  1  0  2022/01/03  00:33:15  90013   0.554167
# ...          ...        ... .. ..         ...       ...    ...        ...
# 55292299  2222-S  19.266626  1  0  2022/01/03  10:18:16  90013  10.304444
# 55357655  2222-S  19.266626  1  0  2022/01/03  11:08:16  90013  11.137778
# 55363988  2222-S  19.266626  1  0  2022/01/03  11:13:15  90013  11.220833
# 55402902  2222-S  19.266626  1  0  2022/01/03  11:43:15  90013  11.720833
# 55422940  2222-S  19.266626  1  0  2022/01/03  11:58:15  90013  11.970833
#
# [141 rows x 8 columns]

# %%
list(set(flow_90013[0].values))
# Out:
# ['5236-S',
#  '2235-S',
#  '2257-S',
#  '5250-S',
#  '2232-S',
#  '5242-N',
#  '2220-W',
#  '2077-S',
#  '2033-W',
#  '2076-E',
#  '2046-N',
#  '2054-E',
#  '2036-W',
#  '2235-N',
#  '2227-S',
#  '2232-N',
#  '2220-E',
#  '2105-N',
#  '2075-S',
#  '2105-S',
#  '2222-S',
#  '2227-N',
#  '2242-S',
#  '2221-E',
#  '2222-E',
#  '2226-W',
#  '2233-E',
#  '2032-W',
#  '2227-W',
#  '2236-W',
#  '2037-S',
#  '2033-N',
#  '2055-E',
#  '2359-S',
#  '2079-S',
#  '2236-S',
#  '2032-N',
#  '2235-W',
#  '2076-N',
#  '2076-S',
#  '2222-N']
